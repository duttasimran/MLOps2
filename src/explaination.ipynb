# %%
from pycaret.classification import *
import pandas as pd

# %%
data = pd.read_csv('../data/iris.csv')
clf = setup(data=data, target='species', session_id=123)

best_model=load_model('models/speciesPrediction')
print(best_model[3])

from pycaret.classification import interpret_model
interpret_model(best_model[3])
# Out:
# <style type="text/css">
# #T_eb06b_row9_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_eb06b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_eb06b_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_eb06b_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_eb06b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_eb06b_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_eb06b_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_eb06b_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_eb06b_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_eb06b_row1_col1" class="data row1 col1" >species</td>
#     </tr>
#     <tr>
#       <th id="T_eb06b_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_eb06b_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_eb06b_row2_col1" class="data row2 col1" >Multiclass</td>
#     </tr>
#     <tr>
#       <th id="T_eb06b_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_eb06b_row3_col0" class="data row3 col0" >Target mapping</td>
#       <td id="T_eb06b_row3_col1" class="data row3 col1" >Iris-setosa: 0, Iris-versicolor: 1, Iris-virginica: 2</td>
#     </tr>
#     <tr>
#       <th id="T_eb06b_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_eb06b_row4_col0" class="data row4 col0" >Original data shape</td>
#       <td id="T_eb06b_row4_col1" class="data row4 col1" >(150, 5)</td>
#     </tr>
#     <tr>
#       <th id="T_eb06b_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_eb06b_row5_col0" class="data row5 col0" >Transformed data shape</td>
#       <td id="T_eb06b_row5_col1" class="data row5 col1" >(150, 5)</td>
#     </tr>
#     <tr>
#       <th id="T_eb06b_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_eb06b_row6_col0" class="data row6 col0" >Transformed train set shape</td>
#       <td id="T_eb06b_row6_col1" class="data row6 col1" >(105, 5)</td>
#     </tr>
#     <tr>
#       <th id="T_eb06b_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_eb06b_row7_col0" class="data row7 col0" >Transformed test set shape</td>
#       <td id="T_eb06b_row7_col1" class="data row7 col1" >(45, 5)</td>
#     </tr>
#     <tr>
#       <th id="T_eb06b_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_eb06b_row8_col0" class="data row8 col0" >Numeric features</td>
#       <td id="T_eb06b_row8_col1" class="data row8 col1" >4</td>
#     </tr>
#     <tr>
#       <th id="T_eb06b_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_eb06b_row9_col0" class="data row9 col0" >Preprocess</td>
#       <td id="T_eb06b_row9_col1" class="data row9 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_eb06b_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_eb06b_row10_col0" class="data row10 col0" >Imputation type</td>
#       <td id="T_eb06b_row10_col1" class="data row10 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_eb06b_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_eb06b_row11_col0" class="data row11 col0" >Numeric imputation</td>
#       <td id="T_eb06b_row11_col1" class="data row11 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_eb06b_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_eb06b_row12_col0" class="data row12 col0" >Categorical imputation</td>
#       <td id="T_eb06b_row12_col1" class="data row12 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_eb06b_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_eb06b_row13_col0" class="data row13 col0" >Fold Generator</td>
#       <td id="T_eb06b_row13_col1" class="data row13 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_eb06b_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_eb06b_row14_col0" class="data row14 col0" >Fold Number</td>
#       <td id="T_eb06b_row14_col1" class="data row14 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_eb06b_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_eb06b_row15_col0" class="data row15 col0" >CPU Jobs</td>
#       <td id="T_eb06b_row15_col1" class="data row15 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_eb06b_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_eb06b_row16_col0" class="data row16 col0" >Use GPU</td>
#       <td id="T_eb06b_row16_col1" class="data row16 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_eb06b_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_eb06b_row17_col0" class="data row17 col0" >Log Experiment</td>
#       <td id="T_eb06b_row17_col1" class="data row17 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_eb06b_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_eb06b_row18_col0" class="data row18 col0" >Experiment Name</td>
#       <td id="T_eb06b_row18_col1" class="data row18 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_eb06b_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_eb06b_row19_col0" class="data row19 col0" >USI</td>
#       <td id="T_eb06b_row19_col1" class="data row19 col1" >d9fa</td>
#     </tr>
#   </tbody>
# </table>
# Transformation Pipeline and Model Successfully Loaded
# LGBMClassifier(bagging_fraction=0.7897102639158713, bagging_freq=0,
#                boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#                feature_fraction=0.6690658984709096, importance_type='split',
#                learning_rate=0.14815552474042337, max_depth=-1,
#                min_child_samples=38, min_child_weight=0.001,
#                min_split_gain=0.3576558496108452, n_estimators=266, n_jobs=-1,
#                num_leaves=161, objective=None, random_state=123,
#                reg_alpha=7.0905445369299996e-09,
#                reg_lambda=3.972381289197141e-09, subsample=1.0,
#                subsample_for_bin=200000, subsample_freq=0)

# %%
plot_model(best_model, plot = 'auc')
plot_model(best_model, plot = 'confusion_matrix')
